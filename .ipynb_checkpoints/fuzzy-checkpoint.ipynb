# %%
# !pip3 install fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# Collecting fuzzywuzzy
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# /home/neer/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import pandas as pd

# %%
df = pd.read_csv('Mapped.csv')

# %%
df.head()
# Out:
#   Distributor Item code                        Company Dscription
# 0     Abreza Dk 600x300             KKWD 300x600-06 PLAIN IVORY-P
# 1     Abreza HL 600x300  KFE 240X060-80 BM-RE T'COTA(Q size PL)-P
# 2     Abreza LT 600x300  KFE 300X300-10 BM-RE COB STONE IV(PLU)-P
# 3         Aclin 600x600    KFE 240X060-80 FRENCH BLACK (R size)-P
# 4      Acton DC 600x600      KFE 400X400-06 BM-REC GREY (PLUS) -P

# %%
c = df['Distributor Item code']

# %%
c
# Out:
# 0        Abreza Dk 600x300
# 1        Abreza HL 600x300
# 2        Abreza LT 600x300
# 3            Aclin 600x600
# 4         Acton DC 600x600
#                ...
# 15817      XTREGR000000S4C
# 15818      XTRENO000000S4C
# 15819      XTREOL000000S4C
# 15820      XTREUM000000S4C
# 15821     Z6SAVLSF0001A43C
# Name: Distributor Item code, Length: 15822, dtype: object

# %%
len(c)
# Out:
# 15822

# %%
#c = c[::15]

# %%
# %%time
process.extract("Abre", c, limit=100, scorer=fuzz.token_sort_ratio)
# Out:
# CPU times: user 823 ms, sys: 0 ns, total: 823 ms
# Wall time: 825 ms
# [('Care Terro', 43, 130),
#  ('Care Terro', 43, 1130),
#  ('Care Terro', 43, 2130),
#  ('Care Terro', 43, 3130),
#  ('Care Terro', 43, 4130),
#  ('Care Terro', 43, 5130),
#  ('Care Terro', 43, 6130),
#  ('Care Terro', 43, 7130),
#  ('Care Terro', 43, 8130),
#  ('Care Terro', 43, 9130),
#  ('Care Terro', 43, 10130),
#  ('Care Terro', 43, 11130),
#  ('Care Terro', 43, 12130),
#  ('Care Terro', 43, 13130),
#  ('Care Terro', 43, 14130),
#  ('Abreza Dk 600x300', 38, 0),
#  ('Abreza HL 600x300', 38, 1),
#  ('Abreza LT 600x300', 38, 2),
#  ('Galaxy Greek', 38, 291),
#  ('Abreza Dk 600x300', 38, 1000),
#  ('Abreza HL 600x300', 38, 1001),
#  ('Abreza LT 600x300', 38, 1002),
#  ('Galaxy Greek', 38, 1291),
#  ('Abreza Dk 600x300', 38, 2000),
#  ('Abreza HL 600x300', 38, 2001),
#  ('Abreza LT 600x300', 38, 2002),
#  ('Galaxy Greek', 38, 2291),
#  ('Abreza Dk 600x300', 38, 3000),
#  ('Abreza HL 600x300', 38, 3001),
#  ('Abreza LT 600x300', 38, 3002),
#  ('Galaxy Greek', 38, 3291),
#  ('Abreza Dk 600x300', 38, 4000),
#  ('Abreza HL 600x300', 38, 4001),
#  ('Abreza LT 600x300', 38, 4002),
#  ('Galaxy Greek', 38, 4291),
#  ('Abreza Dk 600x300', 38, 5000),
#  ('Abreza HL 600x300', 38, 5001),
#  ('Abreza LT 600x300', 38, 5002),
#  ('Galaxy Greek', 38, 5291),
#  ('Abreza Dk 600x300', 38, 6000),
#  ('Abreza HL 600x300', 38, 6001),
#  ('Abreza LT 600x300', 38, 6002),
#  ('Galaxy Greek', 38, 6291),
#  ('Abreza Dk 600x300', 38, 7000),
#  ('Abreza HL 600x300', 38, 7001),
#  ('Abreza LT 600x300', 38, 7002),
#  ('Galaxy Greek', 38, 7291),
#  ('Abreza Dk 600x300', 38, 8000),
#  ('Abreza HL 600x300', 38, 8001),
#  ('Abreza LT 600x300', 38, 8002),
#  ('Galaxy Greek', 38, 8291),
#  ('Abreza Dk 600x300', 38, 9000),
#  ('Abreza HL 600x300', 38, 9001),
#  ('Abreza LT 600x300', 38, 9002),
#  ('Galaxy Greek', 38, 9291),
#  ('Abreza Dk 600x300', 38, 10000),
#  ('Abreza HL 600x300', 38, 10001),
#  ('Abreza LT 600x300', 38, 10002),
#  ('Galaxy Greek', 38, 10291),
#  ('Abreza Dk 600x300', 38, 11000),
#  ('Abreza HL 600x300', 38, 11001),
#  ('Abreza LT 600x300', 38, 11002),
#  ('Galaxy Greek', 38, 11291),
#  ('Abreza Dk 600x300', 38, 12000),
#  ('Abreza HL 600x300', 38, 12001),
#  ('Abreza LT 600x300', 38, 12002),
#  ('Galaxy Greek', 38, 12291),
#  ('Abreza Dk 600x300', 38, 13000),
#  ('Abreza HL 600x300', 38, 13001),
#  ('Abreza LT 600x300', 38, 13002),
#  ('Galaxy Greek', 38, 13291),
#  ('Abreza Dk 600x300', 38, 14000),
#  ('Abreza HL 600x300', 38, 14001),
#  ('Abreza LT 600x300', 38, 14002),
#  ('Galaxy Greek', 38, 14291),
#  ('Cartoon', 36, 133),
#  ('Cartoon', 36, 1133),
#  ('Cartoon', 36, 2133),
#  ('Cartoon', 36, 3133),
#  ('Cartoon', 36, 4133),
#  ('Cartoon', 36, 5133),
#  ('Cartoon', 36, 6133),
#  ('Cartoon', 36, 7133),
#  ('Cartoon', 36, 8133),
#  ('Cartoon', 36, 9133),
#  ('Cartoon', 36, 10133),
#  ('Cartoon', 36, 11133),
#  ('Cartoon', 36, 12133),
#  ('Cartoon', 36, 13133),
#  ('Cartoon', 36, 14133),
#  ('Ambient Crema 300x300', 32, 32),
#  ('Dg Cross Ochare', 32, 223),
#  ('Ambient Crema 300x300', 32, 1032),
#  ('Dg Cross Ochare', 32, 1223),
#  ('Ambient Crema 300x300', 32, 2032),
#  ('Dg Cross Ochare', 32, 2223),
#  ('Ambient Crema 300x300', 32, 3032),
#  ('Dg Cross Ochare', 32, 3223),
#  ('Ambient Crema 300x300', 32, 4032),
#  ('Dg Cross Ochare', 32, 4223)]

# %%
df.shape[0]
# Out:
# 15822

# %%
df.iloc[1]['Distributor Item code']
# Out:
# 'Abreza HL 600x300'

# %%
c = df['Distributor Item code']

# %%
c = df['Distributor Item code'],index==
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-094cf691cdda> in <module>
# ----> 1 c = df['Distributor Item code'],index=False
#
# TypeError: cannot unpack non-iterable bool object

# %%
df.iloc[:,1]
# Out:
# 0                   KKWD 300x600-06 PLAIN IVORY-P
# 1        KFE 240X060-80 BM-RE T'COTA(Q size PL)-P
# 2        KFE 300X300-10 BM-RE COB STONE IV(PLU)-P
# 3          KFE 240X060-80 FRENCH BLACK (R size)-P
# 4            KFE 400X400-06 BM-REC GREY (PLUS) -P
#                            ...
# 15817       VFJ 400X400-8 TREASURE GRIS REC DIG-C
# 15818      VFJ 400X400-8 TREASURE NOIR REC DIG -C
# 15819      VFJ 400X400-8 TREASURE OLIVE REC DIG-C
# 15820      VFJ 400X400-8 TREASURE UMBER REC DIG-C
# 15821           O6VM 600X600-4 SAVLAN SF PO REC-C
# Name: Company Dscription, Length: 15822, dtype: object

# %%
a = list(c)

# %%
a
# Out:
# ['Abreza Dk 600x300',
#  'Abreza HL 600x300',
#  'Abreza LT 600x300',
#  'Aclin 600x600',
#  'Acton DC 600x600',
#  'Adoks Beige 600x600',
#  'Adoks Grey 600x600',
#  'Agates Bianco 600x300',
#  'Agates Nero 600x300',
#  'AGL Beige 600x300',
#  'AGL HL 600x300',
#  'AGL Lite 600x300',
#  'Ajmer Ivory 300x300',
#  'Albano White 800x800',
#  'Albito Lemon 600x600',
#  'Albito White 600x600',
#  'Albury HL 600x300',
#  'Algeria Beige 1200x600',
#  'Almendra SF 600x600',
#  'Almentos Floor 300x300',
#  'Almitos DK 600x300',
#  'Almitos HL 600x300',
#  'Almitos LT 600X300',
#  'Alpine Blue 300x300',
#  'Amaron Bright 600x300',
#  'Amatrix Beige 450x300',
#  'Amatrix Gris 450x300',
#  'Amazon Bright 600x300',
#  'Amazon DK 600x300',
#  'Amazon Floor 300x300',
#  'Amazon Gris 600x600',
#  'Amazon HL 600x300',
#  'Ambient Crema 300x300',
#  'Ambient Decor 600x300',
#  'Ambient DK 600x300',
#  'Ambient LT 600x300',
#  'Ambrosia Gold 1200x600',
#  'American Walnut 1200x300',
#  'American Walnut 1200x600',
#  'Andes Bright 600x300',
#  'Andes HL 600x300',
#  'Antartica White 600x600',
#  'Antique Moss HDR 1200x600',
#  'Antique Rust Splits 1200x200',
#  'Arcade DK 600x300',
#  'Arcade Floor 300x300',
#  'Arcade LT 600x300',
#  'Arcadia Classic 600x600',
#  'Arcadia Pearl 600x600',
#  'Aristo Decor 600x300',
#  'Aristo DK 600x300',
#  'Aristo LT 600x300',
#  'Arizona Liso 1200x600',
#  'Armani Brown 1200x600',
#  'Artist Decor 600x300',
#  'Artiz Andes 300x300',
#  'Artiz Beige Rock 300x300',
#  'Artiz Bruno 300x300',
#  'Artiz Cream 300x300',
#  'Artiz Dyna 300x300',
#  'Artiz Indigo 300x300',
#  'Artiz Mix Cubes 300x300',
#  'Ash Grey 600x600',
#  'Ash Monte 600x600',
#  'Ashley Floor 300x300',
#  'Ashley HL 600x300',
#  'Ashley LT 600x300',
#  'Aston SF 600x600',
#  'Astoria 600x600',
#  'AU Black 600x600',
#  'Autumn Splits 1200x200',
#  'Aveo SF 600x600',
#  'Barstow DK 600x300',
#  'Barstow HL 600x300',
#  'Barstow LT 600x300',
#  'Basalt BRN 300x300',
#  'Belice Wood 800x400',
#  'Bella Pearl 600x400',
#  'Bellapapeir FX 1200x600',
#  'Benalium 600x600',
#  'Benalium Plus 600x600',
#  'Benaluim 1200x300',
#  'Benaluim 1200x600',
#  'Benicrssin BG 600x300',
#  'Benimac DK 450x300',
#  'Benimac Floor 300x300',
#  'Benimac HL 450x300',
#  'Benimac LT 450x300',
#  'BG Bottochino 600x600',
#  'Bianco White 1200x600',
#  'Black 300x300',
#  'Black Cristal Glossy 800x400',
#  'Black Glossy 800x400',
#  'Black Portoro 1200x600',
#  'Blanco Cararra 600x600',
#  'Blanco Neive 600x300',
#  'Blanco Neive Kajaria 450x300',
#  'Blanco Neive Kajaria 600x300',
#  'Blocks Gris 300x300',
#  'Bloom Floor 300x300',
#  'Bloom Flower HL 450x300',
#  'Bloom LT 450x300',
#  'Blue 300x300',
#  'Blue 450x300',
#  'Boiskraft Stripes 800x400',
#  'Bookmac HL 1200x600',
#  'Bottochi Natura 800x800',
#  'Bottochino Classic Liso 1600x800',
#  'Bottochino Royal Liso 1200x600',
#  'Breccia Aurrora 1200x800',
#  'Bubbles Traventine 450x300',
#  'Burberry 600x600',
#  'Cafe Home Decor 600x300',
#  'Calder Mink 1200x600',
#  'Caldo Glo Twin 600x400',
#  'Calista DK 600x300',
#  'Calista HL 600x300',
#  'Calista LT 600x300',
#  'CANDOLIM 600*600',
#  'Canvera Art HL 800x400',
#  'Canyan Brown 400x400',
#  'Canyan Brown Decor 400x400',
#  'Caranz Dark Grey 15MM 300x300',
#  'Cardinal Bright 600x300',
#  'Cardinal Dark 600x300',
#  'Cardinal Decor 600x300',
#  'Care Gris 600x600',
#  'Care Rock 600x600',
#  'Care Spa 600x600',
#  'Care Teak 600x600',
#  'Care Terro',
#  'Cario Beige Liso 1600x800',
#  'Carolina Gold 300x300',
#  'Cartoon',
#  'Cascade Dusk 450x300',
#  'Cascade Liso 1600x800',
#  'Castle Stone BG 600x300',
#  'Castle Stone Gris 600x300',
#  'Castle Stone Moss 600x300',
#  'Cavelo Light Grey 15MM 300x300',
#  'Cementina GY 300x300',
#  'Cementoza Decor 600x300',
#  'Cementoza LT 600x300',
#  'Cementz Natura 800x800',
#  'Ceylon Marfil 600x300',
#  'Ceylon Wood 1200x800',
#  'Checkered Terra 300x300',
#  'Chekered Grey 12MM 300x300',
#  'Chestnut Floor 300x300',
#  'Chestnut HL 600x300',
#  'Chestnut LT 600x300',
#  'Chipstone Gris 600x300',
#  'Chisel Granite Beige 600x300',
#  'Chisel Granite DK Grey 600x300',
#  'Clare Onyx 600x600',
#  'Classic DK 600x300',
#  'Classic LT 600x300',
#  'Classic Pearl 600x600',
#  'Cliff DK 600x300',
#  'Cloud DK 450x300',
#  'Cloud Floor 300x300',
#  'Cloud HL 450x300',
#  'Cloud LT 450x300',
#  'Coated Black 300x300',
#  'Coated Grey 10MM 300x300',
#  'Coated Grey 12MM 300x300',
#  'Coated Grey 15MM 300x300',
#  'Coated White 12MM 300x300',
#  'Cobble Stone Ivory 10MM 300x300',
#  'Cobble Stone Terra 10MM 300x300',
#  'Colorado Hl 450x300',
#  'Cool Ivory Rotto Matt 600x600',
#  'Cool Roof Tile 300x300',
#  'Copper Cloudy 300x300',
#  'Cosmic Choco Dc',
#  'Cotto 600x300',
#  'Cotto Blocks 600x300',
#  'Cotto Waves 600x300',
#  'Cozi Base 450x300',
#  'Cozi Floor 300x300',
#  'Cozi HL 450x300',
#  'Creama 450x300',
#  'Crema 1200x600',
#  'Crema 450x300',
#  'Crema 600x300',
#  'Crema Athos 600x600',
#  'Cross Chalk 300x300',
#  'Crust Monte 600x600',
#  'Crystal Beige 600x600',
#  'Crystillano Gold 600x600',
#  'Cudjee DK 600x300',
#  'Cudjee Floor 300x300',
#  'Cudjee HL 600x300',
#  'Cudjee LT 600x300',
#  'Cunix Beige 1200x600',
#  'Cyprus Plazma 800x1600',
#  'Daino Beige 600x600',
#  'Daino Gold 600x600',
#  'Damask Classic 600x400',
#  'Damask Royale 600x400',
#  'Dawn Bright 600x300',
#  'Dawn Deep 600x300',
#  'Dawn HL 600x300',
#  'Dazzle 1200x800',
#  'DC Ivory 600x600',
#  'DC LEMON 600X600',
#  'DC White 1200x600',
#  'DC WHITE 600X600',
#  'Decor Himalayan 600x300',
#  'Decostone Black 600x300',
#  'Decostone Decor 600x300',
#  'Decostone White 600x300',
#  'Deliant LT 600x300',
#  'Denim Cobalt 1200x600',
#  'Desert Bianco 600x600',
#  'Desert Crema 600x600',
#  'Desert Grey 600x300',
#  'Desert Umber 300x300',
#  'Desert Verde 600x600',
#  'Dessert Pearl 1200x800',
#  'Dew Black Matt 600x600',
#  'Dew Grey 600x600',
#  'Dew Grey Matt 600x600',
#  'Dg Cross Ochare',
#  'Dona Bianco 450x300',
#  'Dona Nero 450x300',
#  'Donapola 600x600',
#  'Dove Sheen Rasso 800x800',
#  'Dover DK 450x300',
#  'Dover Floor 300x300',
#  'Dover LT 450x300',
#  'Drift Cotto 400x400',
#  'Drift Mix 400x400',
#  'Dyansty Liso Gold 1200x600',
#  'Dyna AGL 300x300',
#  'Dyna DK 600x300',
#  'Dyna Floor 300x300',
#  'Dyna Italiano',
#  'Dyna LT 600x300',
#  'Dynas Beige 600x300',
#  'Earth Beige 600x600',
#  'Earth Bruno 600x600',
#  'Earth Eclat 600x400',
#  'Earth Gris 600x600',
#  'Earth Ivory 600x600',
#  'Earth Ochre 600x600',
#  'Earth Snow 600x600',
#  'Earth Span 600x400',
#  'Earth Steel Grey 600x600',
#  'Easel HDR 1200x600',
#  'Egypto Brown 600x600',
#  'Eleganza Decor 600x300',
#  'Eleganza DK 600x300',
#  'Eleganza LT 600x300',
#  'Ellora Black 300x300',
#  'Emola Decor 600x300',
#  'Emola DK 600x300',
#  'Emola LT 600x300',
#  'Empeira Floor 300x300',
#  'Empeira HL 450x300',
#  'Emperador 1200x600',
#  'Emperador Ivory 600x300',
#  'Emperador Quadra HL 600x300',
#  'Emperia Bright 450x300',
#  'Emperia Deep 450x300',
#  'Eritea DK 450x300',
#  'Eritea Floor 300x300',
#  'Eritea HL 450x300',
#  'Eritea LT 450x300',
#  'Espanya HL 450x300',
#  'Euro Empredor 1200x600',
#  'Exotic Decor Relief 600x300',
#  'Exotic White Relief 600x300',
#  'Fantasy Gold 1200x600',
#  'Fiona Florina HL GY BK 600x300',
#  'Flocept DK 300x300',
#  'Flocept LT 300x300',
#  'Floor Tiles 300x300',
#  'Floor Tiles 400x400',
#  'Florano LT 600x300',
#  'Florence LT 450x300',
#  'Flow Mocha 1200x600',
#  'Fluence Beige 450x300',
#  'Fluence Choco 450x300',
#  'Flurry Dc',
#  'Fontana HL 600x300',
#  'Fontana LT 600x300',
#  'Frances GRN HL 450x300',
#  'Frances GRN LT 450x300',
#  'Frost Dusk 1200x600',
#  'Frost White 600x600',
#  'Galaxy Greek',
#  'Garnet Quadra 600x300',
#  'Garnet Quadra HL 600x300',
#  'Gemma DK 450x300',
#  'Gemma Floor 300x300',
#  'Gemma HL 450x300',
#  'Gemma LT 450x300',
#  'Glare Four 600X400',
#  'Glass Glow Club 800x400',
#  'Glenco Beige 600x300',
#  'Glenco Crema 600x300',
#  'Glenco HL 600x300',
#  'Glory 1200x800',
#  'Golden Onyx 1200x600',
#  'Gracia Bright 600x300',
#  'Gracia Feature 800x400',
#  'Graffiti Bright 450x300',
#  'Graffiti Deep 450x300',
#  'Graffiti Floor 300x300',
#  'Graffiti HL 450x300',
#  'Grain Magic HL 450x300',
#  'Grainflow DK 450x300',
#  'Grainflow Floor 300x300',
#  'Grainflow LT 450x300',
#  'Grande Traventino 600x300',
#  'Granilia Cobalt Blue 300x300',
#  'Graniti Feature 800x400',
#  'Graniti Mix 800x400',
#  'Graniti White 800x400',
#  'Grazia Plazma 1600x800',
#  'Green Endura 10MM 300x300',
#  'Greenland Quartz 600x600',
#  'Grey 300x200',
#  'Grey 300x300',
#  'Grey Endura 10MM 300x300',
#  'Grey Endura 12MM 300x300',
#  'Grey Plus 10MM 300x300',
#  'Grey Plus 12MM 300x300',
#  'Grid Line LT 450x300',
#  'Gristone DK 600x300',
#  'Gristone LT 600x300',
#  'Gritty Branco 16MM 600x600',
#  'Gritty Crust 16MM 600x600',
#  'Heritage Floor 300x300',
#  'Heritage HL 600x300',
#  'Heritage LT 600x300',
#  'Heritage Verde DK 600x300',
#  'Imperial Bianco 1200x600',
#  'Imperial Pearl 600x300',
#  'Impresso White 300x300',
#  'Indigo DK 600x300',
#  'Indigo HL 600x300',
#  'Indigo LT 600x300',
#  'Inflexion Blanco 600x300',
#  'Ingle Wood DK 600x300',
#  'Ingle Wood Floor 300x300',
#  'Ingle Wood HL 600x300',
#  'Ingle Wood LT 600x300',
#  'Inspira DK 450x300',
#  'Inspira Floor 300x300',
#  'Inspira HL 450x300',
#  'Inspira LT 450x300',
#  'Ivory 12MM 300x300',
#  'Ivory 20MM 300x300',
#  'Ivory 300x200',
#  'Ivory 300x300',
#  'Ivory 400x400',
#  'Ivory 600x600',
#  'Ivory 8x4 12MM',
#  'Ivory 8x4 20MM',
#  'Ivory Endura 15MM 300x300',
#  'Ivory Plus 10MM 300x300',
#  'Ivory SF 600x600',
#  'Ivy Twin 600x400',
#  'Jasper Crema 1200x600',
#  'Jet Black 1200x600',
#  'Jet Black 600x600',
#  'Jodaro Bright 600x300',
#  'Jodaro DK 600x300',
#  'Jodaro Feature 600x300',
#  'Jodhpur Beige 300x300',
#  ' Endura Ivory 10MM 300x300',
#  'Jupiter 600x600',
#  'Jurawood 600x300',
#  'Kajaria 6212 600x600',
#  'Kayla Bright 450x300',
#  'Kayla Decor 450x300',
#  'Kayla Deep 450x300',
#  'Keive Dk 600x300',
#  'Keive Floor 300x300',
#  'Kerasix Ferro 600x400',
#  'Kerasix Ivory 600x400',
#  'Kerasix Rhytm 600x400',
#  'Koel Satvario 800x800',
#  'Korneto Beige 600x600',
#  'Korrel DC 600x600',
#  'Kraft Crust 400x400',
#  'Kraft Earth 400x400',
#  'Kraft Exotica White 400x400',
#  'Kraft Moon 400x400',
#  'Kraft Neptune 400x400',
#  'Kraft Pinewood 400x400',
#  'Kreo Ivory 20MM 600x600',
#  'Lagnum Beige 600x300',
#  'Lagnum Brown 300x300',
#  'Lagnum Brown 600x300',
#  'Lapato German Wooden 600x600',
#  'Lapis Natura 1200x600',
#  'Laurento Sheen 800x400',
#  'Laverna Decor 600x300',
#  'Laverna DK 600x300',
#  'Laverna White 600x300',
#  'Lazurite Beige 450x300',
#  'Lazurite Gris 450x300',
#  'Ledgestone Beige 600x300',
#  'Ledgestone Brown 600x300',
#  'Lenox Beige 300x300',
#  'Lenox Beige 600x600',
#  'Lenox Blanco 300x300',
#  'Lenox Blue 300x300',
#  'Lenox Brown 600x600',
#  'Lenox Crema 300x300',
#  'Lenox Gris 300x300',
#  'Lenox Lavender 300x300',
#  'Lenox Pink 300x300',
#  'Lenox Verde 300x300',
#  'Leone HL 600x300',
#  'Leone LT 600x300',
#  'Ligo Art HL 450x300',
#  'Ligo DK 450x300',
#  'Ligo Floor 300x300',
#  'Ligo LT 450x300',
#  'Linia Crema 450x300',
#  'Lisa Unico 600x600',
#  'Lowena Bright 600x300',
#  'Lowena Decor 600x300',
#  'Lowena DK 600x300',
#  'Lumber Dazzle Splt 1200x200',
#  'Macau Beige 600x600',
#  'Maderia Onyx 1200x600',
#  'Magna Pine 800x400',
#  'Mango Yellow 600x600',
#  'Mangolia Grey 600x300',
#  'Manila Ocre 400x400',
#  'Mapple Brown 600x600',
#  'Marisol Olive Dk 600x300',
#  'Marisol Olive Floor 300x300',
#  'Marisol Olive HL 600x300',
#  'Marisol Olive LT 600x300',
#  'Marisol Rose Dk 600x300',
#  'Marisol Rose Floor 300x300',
#  'Marisol Rose HL600x300',
#  'Marisol Rose LT 600x300',
#  'Marmal KIT HL 2 450x300',
#  'Marmi Crema 1200x600',
#  'Marmol Snow 450x300',
#  'Marmol Snow HL 450x300',
#  'Marmos BG 1200x600',
#  'Marmos Brown 1200x600',
#  'Marquina Marble 1200x600',
#  'Marron Choco 1200x600',
#  'Matrix Blanco 450x300',
#  'Matrix Gris 450x300',
#  'Matrix White 600x600',
#  'MCPL 24241 600X600',
#  'Mega White 600x600',
#  'Melwak Oak LT 600x300',
#  'Merbau Figo Brown 450x300',
#  'Metachalk Split 1200x200',
#  'Metachalk Splits 1200x200',
#  'Metawood Splits',
#  'Metawood Splits 1200x200',
#  'Meteor FX Nero 1200x600',
#  'Meteor FX White 1200x600',
#  'Mid Night Black 1200x600',
#  'Miramar 600x600',
#  'Miramar Plus Commercial 10MM 600x600',
#  'Mismo Copper 600x600',
#  'Mist Grey 600x600',
#  'Mistic Bright 450x300',
#  'Mix Stone Gris 300x300',
#  'Moca Art HL 600x300',
#  'Moca DK 600x300',
#  'Moca Floor 300x300',
#  'Moca LT 600x300',
#  'Modish Planks 1200x600',
#  'Moldova Nero BKM A 800x1600',
#  'Moon Span 600x400',
#  'Mosaico Grey 300x300',
#  'Mozaico Ochre 600x400',
#  'Mozil Brown 600x300',
#  'Mozil Ivory 600x300',
#  'Murreto DK 600x300',
#  'Murreto LT 600x300',
#  'Nautica Sasso 1200x600',
#  'Nebulia DK 600x300',
#  'Nebulia HL 600x300',
#  'Nebulia LT 600x300',
#  'Neives SF 600x600',
#  'Nelson 600x600',
#  'Nelson LT 600x300',
#  'Neo Dune Bright 600x300',
#  'Neo Dune Centric 600x300',
#  'Neo Dune Deep 600x300',
#  'Neron Snow 800x800',
#  'New Blue 108x108',
#  'New Blue 300x200',
#  'New Tek Bt Yellow 300x300',
#  'New Tek LN Yellow 300x300',
#  'Niagara Cotto 600x600',
#  'Niagara Crema 600x600',
#  'Noche Ellegante 1200x800',
#  'Nysa DK 450x300',
#  'Nysa Floor 300x300',
#  'Nysa HL 450x300',
#  'Nysa LT 450x300',
#  'Oak Decor 800x400',
#  'Oak Emotion 800x400',
#  'Oak Wood Ash 600x300',
#  'Oak Wood Natura 600x300',
#  'Ocatavia Beige 600x300',
#  'Ocatvia HL 600x300',
#  'Octavia Creama 600x300',
#  'Octavia Floor 300x300',
#  'Octavia HL 600x300',
#  'Odell Azul 600x300',
#  'Odell Floor 300x300',
#  'Odell HL 600x300',
#  'Odell LT 600x300',
#  'Ohio Wood 1200x800',
#  'Olivia Crema 1200x600',
#  'Olympia Bianco 1200x600',
#  'Onio Decor 600x300',
#  'Onio White 600x300',
#  'Opera Brown 1200x600',
#  'Opus Liso 1200x600',
#  'Osaka Meadow 600x600',
#  'Oxford Gris 600x600',
#  'Oxido Crimson 1200x200',
#  'Oxido Crimson 1200x300',
#  'Ozar Wood Floor 300x300',
#  'Ozark Wood DK 600x300',
#  'Ozark Wood HL 600x300',
#  'Ozark Wood LT 600x300',
#  'Paloma Nero 800x1600',
#  'Panoroma DC 600x600',
#  'Paradiso LT 600x300',
#  'Paradiso Waves LT 600x300',
#  'Parian White 1200x800',
#  'Parx Gris 300x300',
#  'Pearl Cristal Nero 600x400',
#  'Pearl Cristal Snow 600x400',
#  'Pearl Cristal Symphony 600x400',
#  'Pearl Onyx 800x800',
#  'Pearl Sheen 800x400',
#  'Pearl White 800x800',
#  'Perito TW 600x600',
#  'Perlato Sicillia 800x800',
#  'Phoenix DK 600x300',
#  'Phoenix Floor 300x300',
#  'Phoenix HL 600x300',
#  'Phoenix Light 600x300',
#  'Piacentina Beige 600x600',
#  'Pink Stone 1200x300',
#  'Plain Benaulium 1200x300',
#  'Plain Donapaula 1200x600',
#  'Plain Traventine 450x300',
#  'Plain Tropic White 450x300',
#  'Plank Natural 600x600',
#  'Plazo Graphite 600x600',
#  'Pobles Floor 300x300',
#  'Pobles HL 450x300',
#  'Pobles LT 450x300',
#  'Polka Rectangle Ivory 10MM 300x300',
#  'Polka Rectangle Terracotta 10MM 300x300',
#  'Polka Strip Ivory 10MM 300x300',
#  'Pool Tile Dark Blue 247x122',
#  'Pool Tile New Blue 247x122',
#  'Porphiry Pearl 800x400',
#  'Portland White Feather 1600x800',
#  'Portland White Liso 800x1600',
#  'Prada DK 450x300',
#  'Prada HL 450x300',
#  'Prada LT 450x300',
#  'Pretoria Noce 600x600',
#  'Pretoria Noce 800x400',
#  'Pretoria Noce Decor 800x400',
#  'Pretoria Tan 800x400',
#  'Pretoria Tan Decor 800x400',
#  'Pulpis Beige 1200x600',
#  'Purbeck Beige 1200x800',
#  'Quarjet DK 600x300',
#  'Quarjet Floor 300x300',
#  'Quarjet HL 600x300',
#  'Quarjet LT 600x300',
#  'Quart HL 450x300',
#  'Quart LT 450x300',
#  'Quartz Grey 300x300',
#  'Quincy DK 600x300',
#  'Quincy HL 600x300',
#  'Quincy LT 600x300',
#  'Randolph 600x300',
#  'Randolph Floor 300x300',
#  'Randolph HL 600x300',
#  'Rascanya Lilac DK 450x300',
#  'Rascanya Lilac Floor 300x300',
#  'Rascanya Lilac HL 450x300',
#  'Rascanya Lilac LT 450x300',
#  'Rascanya Pink DK 450x300',
#  'Rascanya Pink HL 450x300',
#  'Rascanya Pink LT 450x300',
#  'Recent DK 450x300',
#  'Recent Floor 300x300',
#  'Recent HL 450x300',
#  'Recent LT 450x300',
#  'Red 10MM 300x300',
#  'Renet Iv Brown 300x200',
#  'Ret IV 600x300',
#  'Ret Piazza HL 600x300',
#  'Retro Block DK 600x300',
#  'Retro Block LT 600x300',
#  'Retro Decor 600x300',
#  'Revoke Beige 600x600',
#  'Rezorto Blocks 600x400',
#  'RH145 600X300',
#  'Rhombus Pearl 600x300',
#  'Rialto Mosaico HL 600x300',
#  'Richmonte Liso White 1200x600',
#  'Rio Bright 600x300',
#  'Rio DK 600x300',
#  'Rio Magic 600x300',
#  'River Satvario A 1200x600',
#  'Rivera Beige 600x300',
#  'Rivo DK 450x300',
#  'Rivo Floor',
#  'Rivo LT 450x300',
#  'Rivo Mix HL 450x300',
#  'Rizzoli DK 450x300',
#  'Rizzoli Floor 300x300',
#  'Rizzoli HL 450x300',
#  'Rizzoli LT 450x300',
#  'Rock Damask Gris 800x400',
#  'Rock Decor Brown 800x400',
#  'Rock Face BG 800x400',
#  'Rock Face Grey 450x300',
#  'Rock Stone BG 600X300',
#  'Rock Stone Gris 600x300',
#  'Rock Stone Shell 600x300',
#  'Rockstone Natural 600x300',
#  'Rodas Art HL 600x300',
#  'Rodas DK 600x300',
#  'Rodas Floor 300x300',
#  'Rodas LT 600x300',
#  'Romania Black 1200x600',
#  'Romano DC 600x600',
#  'Rosinca 450x300',
#  'Royal Beige 1200x800',
#  'Royal Blue 108x108',
#  'Royal Marfil 450x300',
#  'Royal Marfil Floor 300x300',
#  'Royal Marfil HL 450x300',
#  'Royal Satvario 1200x600',
#  'Rusterio DK 600x300',
#  'Rusterio HL 600x300',
#  'Rusterio LT 600x300',
#  'Rustic Vibe Valley 600x600',
#  'Rustic Vibes Dune 600x600',
#  'S Triassic Latte 600x600',
#  'S&P BLACK 200X200',
#  'S&P GREY 200X200 10MM',
#  'S&P Grey 600X600',
#  'S&P Grey C 600x600',
#  'S&P White 12MM 200x200',
#  'S&P White 200x200',
#  'S&P White 600x600',
#  'S&P White 800x800',
#  'S&P White C 600x600',
#  'Sahara Ash 1200x600',
#  'Sahara Crema 1200x600',
#  'Sandra 600x600',
#  'Sandune Crema 600x600',
#  'Saphire Nero 600x600',
#  'Sapphire Floor 300x300',
#  'Sapphire HL 450x300',
#  'Sapphire LT 450x300',
#  'Satvario Grande 800x800',
#  'Satvario HL 450x300',
#  'Satvario LT 450x300',
#  'Season DK 450x300',
#  'Season Floor 300x300',
#  'Season HL 450x300',
#  'Season LT 450x300',
#  'Sequira Chess 600x300',
#  'Serenity DC 600x600',
#  'SG Capsule Terra Plus 300x300',
#  'Shale White 300x300',
#  'Shell Decor 600x300',
#  'Shell LT 600x300',
#  'Sicilia White 600x600',
#  'Sicillia Lemon 600x600',
#  'Silver Grey Plus 12MM 300x300',
#  'Silver Grey Plus 15MM 200x100',
#  'Skoda Coffee 300x300',
#  'Sky 800x400',
#  'Sky Sepal 800x400',
#  'Slate DK Grey 300x300',
#  'Slate LT BG 300x300',
#  'Slate LT Grey 300x300',
#  'Snow 450x300',
#  'Snow Allure 800x800',
#  'Sophie Bright 600x300',
#  'Sophie Deep 600x300',
#  'Sophie HL 600x300',
#  'Spruce Ashwood 600x600',
#  'Spruce Beechwood',
#  'SSR Gris 600X600',
#  'Stone Block BG 600x600',
#  'Stone Block GY 600x600',
#  'Stone Mix Grey 300x300',
#  'Stonecept DK 300x300',
#  'Stonecept LT 300x300',
#  'Sun Bright Dekor 600x300',
#  'Supple Cementz 800x800',
#  'Supple Empro 800x800',
#  'Sydney Brown 300x300',
#  'Taco Lava 1200x600',
#  'Tata Blue 10MM 300x300',
#  'Teak Decor 600x400',
#  'Teak Feel 600x600',
#  'Teak Twin 600x400',
#  'Terra 800x400',
#  'Terra Decor 800x400',
#  'Terra Feature 800x400',
#  'Terracotta 10MM 300X300',
#  'Terracotta 600x600',
#  'Terracotta 8x4 20MM',
#  'Texas Nero 1200x600',
#  'Third Fin Four 600x400',
#  'Third Fin Six 600x400',
#  'Tiles',
#  'Tiles 1200x600',
#  'Tiles 375x250',
#  'Tiles 400x400',
#  'Tiles 450x300',
#  'Tiles 600x600',
#  'Tiles 800x400',
#  'Tiles 800x800',
#  'Timber Ash 1200x200',
#  'Timber Oak 1200x200',
#  'To Blue Plus 12MM 300x300',
#  'To Green Endura 12MM 300x300',
#  'To Green Plus 300x300',
#  'To Yellow Plus 12MM 300x300',
#  'To Yellow Plus 300x300',
#  'Toronto Marble 1200x600',
#  'Torrean Deco 600x300',
#  'Torrean LT 600x300',
#  'Torrence Bg 600x600',
#  'Torrento Grey 600x600',
#  'Tosso Pearl 1200x800',
#  'Touch Blaco 600x600',
#  'Touch Tulip Wood 600x600',
#  'Touch Wood 600x600',
#  'Touch Wood Dark 600x600',
#  'Tradiz Beige 300x300',
#  'Tranquil DC 600x600',
#  'Traventino Natura 1200x600',
#  'Traville Bright 600x300',
#  'Traville Dark 600x300',
#  'Traville Decor 600x300',
#  'Travio 600x600',
#  'Travio Gris 600x600',
#  'Travio Silver Rasso 1200x600',
#  'Travis Liso 1200x600',
#  'Traviz Beige 800x800',
#  'Traviz Gris 800x800',
#  'Treiniano Liso 1200x600',
#  'Trendz Cotto 400x400',
#  'Trendz Cotto Deco 400x400',
#  'Tropic White',
#  'Tropic White 450x300',
#  'Truerock Dolomite 600x400',
#  'Truerock Ferro 600x400',
#  'Truerock Fossil 600x400',
#  'Truerock Quartize 600x400',
#  'Trunk Sleeper 300x300',
#  'Trunk Vogue 300x300',
#  'Tunisia LT 450x300',
#  'Turia DK 450x300',
#  'Turia Floor 300x300',
#  'Turia HL 450x300',
#  'Turia LT 450x300',
#  'Turkish Moss 600x600',
#  'Ubania Scuro Base 800x400',
#  'Valencia 600x300',
#  'Valencia Crema 1200x600',
#  'Valeria TW SF 800x800',
#  'Vanilla Gris 600x600',
#  'Velsova 1200x300',
#  'Velsova 1200x600',
#  'Venus Span 600x400',
#  'Victoria Grey 1200x600',
#  'Vintage Dusk 450x300',
#  'Vivo Cotto 600x600',
#  'Wall Art HL 450x300',
#  'Wall Tiles 300x200',
#  'Wall Tiles 450x300',
#  'Wall Tiles 600x200',
#  'Wall Tiles 600x300',
#  'Walnut Lumber 1200x600',
#  'Wavy Terracotta 10MM 300x300',
#  'Weil Keuz Dazzle 800x800',
#  'Wenge Feel 600x600',
#  'Wengee Beech 450x300',
#  'White 300x200',
#  'White 300x300',
#  'White 600x600',
#  'White 8x12',
#  'White L 300x200',
#  'White Plus Endura 10MM 300x300',
#  'Wings Pacific HL 600x300',
#  'Wood Nutmeg 600x600',
#  'Wunder Natura 800x800',
#  'Yellow Endura 10MM 300x300',
#  'Yellow Endura 12MM 300x300',
#  'Zager Wengee 400x400',
#  'Zebrano Beige Liso 800x1600',
#  'Zona DK 450x300',
#  'Zona Floor 300x300',
#  'Zorion Bright 600x300',
#  'Zorion Dark 600x300',
#  'Zorion Decor 600x300',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Distributor Item code',
#  ...]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def get_match(query, choice, limit=10):
    print(query)
    print(choice)
    result = process.extract(query,choice,limit=limit)
    print(result)

# %%
get_match(df.iloc[0]['Distributor Item code'],a)
# Out:
# Abreza Dk 600x300
# ['Abreza Dk 600x300', 'Abreza HL 600x300', 'Abreza LT 600x300', 'Aclin 600x600', 'Acton DC 600x600', 'Adoks Beige 600x600', 'Adoks Grey 600x600', 'Agates Bianco 600x300', 'Agates Nero 600x300', 'AGL Beige 600x300', 'AGL HL 600x300', 'AGL Lite 600x300', 'Ajmer Ivory 300x300', 'Albano White 800x800', 'Albito Lemon 600x600', 'Albito White 600x600', 'Albury HL 600x300', 'Algeria Beige 1200x600', 'Almendra SF 600x600', 'Almentos Floor 300x300', 'Almitos DK 600x300', 'Almitos HL 600x300', 'Almitos LT 600X300', 'Alpine Blue 300x300', 'Amaron Bright 600x300', 'Amatrix Beige 450x300', 'Amatrix Gris 450x300', 'Amazon Bright 600x300', 'Amazon DK 600x300', 'Amazon Floor 300x300', 'Amazon Gris 600x600', 'Amazon HL 600x300', 'Ambient Crema 300x300', 'Ambient Decor 600x300', 'Ambient DK 600x300', 'Ambient LT 600x300', 'Ambrosia Gold 1200x600', 'American Walnut 1200x300', 'American Walnut 1200x600', 'Andes Bright 600x300', 'Andes HL 600x300', 'Antartica White 600x600', 'Antique Moss HDR 1200x600', 'Antique Rust Splits 1200x200', 'Arcade DK 600x300', 'Arcade Floor 300x300', 'Arcade LT 600x300', 'Arcadia Classic 600x600', 'Arcadia Pearl 600x600', 'Aristo Decor 600x300', 'Aristo DK 600x300', 'Aristo LT 600x300', 'Arizona Liso 1200x600', 'Armani Brown 1200x600', 'Artist Decor 600x300', 'Artiz Andes 300x300', 'Artiz Beige Rock 300x300', 'Artiz Bruno 300x300', 'Artiz Cream 300x300', 'Artiz Dyna 300x300', 'Artiz Indigo 300x300', 'Artiz Mix Cubes 300x300', 'Ash Grey 600x600', 'Ash Monte 600x600', 'Ashley Floor 300x300', 'Ashley HL 600x300', 'Ashley LT 600x300', 'Aston SF 600x600', 'Astoria 600x600', 'AU Black 600x600', 'Autumn Splits 1200x200', 'Aveo SF 600x600', 'Barstow DK 600x300', 'Barstow HL 600x300', 'Barstow LT 600x300', 'Basalt BRN 300x300', 'Belice Wood 800x400', 'Bella Pearl 600x400', 'Bellapapeir FX 1200x600', 'Benalium 600x600', 'Benalium Plus 600x600', 'Benaluim 1200x300', 'Benaluim 1200x600', 'Benicrssin BG 600x300', 'Benimac DK 450x300', 'Benimac Floor 300x300', 'Benimac HL 450x300', 'Benimac LT 450x300', 'BG Bottochino 600x600', 'Bianco White 1200x600', 'Black 300x300', 'Black Cristal Glossy 800x400', 'Black Glossy 800x400', 'Black Portoro 1200x600', 'Blanco Cararra 600x600', 'Blanco Neive 600x300', 'Blanco Neive Kajaria 450x300', 'Blanco Neive Kajaria 600x300', 'Blocks Gris 300x300', 'Bloom Floor 300x300', 'Bloom Flower HL 450x300', 'Bloom LT 450x300', 'Blue 300x300', 'Blue 450x300', 'Boiskraft Stripes 800x400', 'Bookmac HL 1200x600', 'Bottochi Natura 800x800', 'Bottochino Classic Liso 1600x800', 'Bottochino Royal Liso 1200x600', 'Breccia Aurrora 1200x800', 'Bubbles Traventine 450x300', 'Burberry 600x600', 'Cafe Home Decor 600x300', 'Calder Mink 1200x600', 'Caldo Glo Twin 600x400', 'Calista DK 600x300', 'Calista HL 600x300', 'Calista LT 600x300', 'CANDOLIM 600*600', 'Canvera Art HL 800x400', 'Canyan Brown 400x400', 'Canyan Brown Decor 400x400', 'Caranz Dark Grey 15MM 300x300', 'Cardinal Bright 600x300', 'Cardinal Dark 600x300', 'Cardinal Decor 600x300', 'Care Gris 600x600', 'Care Rock 600x600', 'Care Spa 600x600', 'Care Teak 600x600', 'Care Terro', 'Cario Beige Liso 1600x800', 'Carolina Gold 300x300', 'Cartoon', 'Cascade Dusk 450x300', 'Cascade Liso 1600x800', 'Castle Stone BG 600x300', 'Castle Stone Gris 600x300', 'Castle Stone Moss 600x300', 'Cavelo Light Grey 15MM 300x300', 'Cementina GY 300x300', 'Cementoza Decor 600x300', 'Cementoza LT 600x300', 'Cementz Natura 800x800', 'Ceylon Marfil 600x300', 'Ceylon Wood 1200x800', 'Checkered Terra 300x300', 'Chekered Grey 12MM 300x300', 'Chestnut Floor 300x300', 'Chestnut HL 600x300', 'Chestnut LT 600x300', 'Chipstone Gris 600x300', 'Chisel Granite Beige 600x300', 'Chisel Granite DK Grey 600x300', 'Clare Onyx 600x600', 'Classic DK 600x300', 'Classic LT 600x300', 'Classic Pearl 600x600', 'Cliff DK 600x300', 'Cloud DK 450x300', 'Cloud Floor 300x300', 'Cloud HL 450x300', 'Cloud LT 450x300', 'Coated Black 300x300', 'Coated Grey 10MM 300x300', 'Coated Grey 12MM 300x300', 'Coated Grey 15MM 300x30 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-9391575c2330> in <module>
# ----> 1 get_match(df.iloc[0]['Distributor Item code'],a)
#
# <ipython-input-82-0f198c2fce33> in get_match(query, choice, limit)
#       5     print(query)
#       6     print(choice)
# ----> 7     result = process.extract(query,choice,10)
#       8     print(result)
#
# ~/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/process.py in extract(query, choices, processor, scorer, limit)
#     166     """
#     167     sl = extractWithoutOrder(query, choices, processor, scorer)
# --> 168     return heapq.nlargest(limit, sl, key=lambda i: i[1]) if limit is not None else \
#     169         sorted(sl, key=lambda i: i[1], reverse=True)
#     170
#
# ~/anaconda3/lib/python3.7/heapq.py in nlargest(n, iterable, key)
#     567     # General case, slowest method
#     568     it = iter(iterable)
# --> 569     result = [(key(elem), i, elem) for i, elem in zip(range(0, -n, -1), it)]
#     570     if not result:
#     571         return result
#
# ~/anaconda3/lib/python3.7/heapq.py in <listcomp>(.0)
#     567     # General case, slowest method
#     568     it = iter(iterable)
# --> 569     result = [(key(elem), i, elem) for i, elem in zip(range(0, -n, -1), it)]
#     570     if not result:
#     571         return result
#
# ~/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#      76
#      77     # Run the processor on the input query.
# ---> 78     processed_query = processor(query)
#      79
#      80     if len(processed_query) == 0:
#
# TypeError: 'int' object is not callable

# %%
df.iloc[0]['Distributor Item code']
# Out:
# 'Abreza Dk 600x300'

# %%
df.shape
# Out:
# (15822, 2)

# %%
get_match(df.iloc[15821]['Distributor Item code'],a)
# Out:
# Z6SAVLSF0001A43C
# ['Abreza Dk 600x300', 'Abreza HL 600x300', 'Abreza LT 600x300', 'Aclin 600x600', 'Acton DC 600x600', 'Adoks Beige 600x600', 'Adoks Grey 600x600', 'Agates Bianco 600x300', 'Agates Nero 600x300', 'AGL Beige 600x300', 'AGL HL 600x300', 'AGL Lite 600x300', 'Ajmer Ivory 300x300', 'Albano White 800x800', 'Albito Lemon 600x600', 'Albito White 600x600', 'Albury HL 600x300', 'Algeria Beige 1200x600', 'Almendra SF 600x600', 'Almentos Floor 300x300', 'Almitos DK 600x300', 'Almitos HL 600x300', 'Almitos LT 600X300', 'Alpine Blue 300x300', 'Amaron Bright 600x300', 'Amatrix Beige 450x300', 'Amatrix Gris 450x300', 'Amazon Bright 600x300', 'Amazon DK 600x300', 'Amazon Floor 300x300', 'Amazon Gris 600x600', 'Amazon HL 600x300', 'Ambient Crema 300x300', 'Ambient Decor 600x300', 'Ambient DK 600x300', 'Ambient LT 600x300', 'Ambrosia Gold 1200x600', 'American Walnut 1200x300', 'American Walnut 1200x600', 'Andes Bright 600x300', 'Andes HL 600x300', 'Antartica White 600x600', 'Antique Moss HDR 1200x600', 'Antique Rust Splits 1200x200', 'Arcade DK 600x300', 'Arcade Floor 300x300', 'Arcade LT 600x300', 'Arcadia Classic 600x600', 'Arcadia Pearl 600x600', 'Aristo Decor 600x300', 'Aristo DK 600x300', 'Aristo LT 600x300', 'Arizona Liso 1200x600', 'Armani Brown 1200x600', 'Artist Decor 600x300', 'Artiz Andes 300x300', 'Artiz Beige Rock 300x300', 'Artiz Bruno 300x300', 'Artiz Cream 300x300', 'Artiz Dyna 300x300', 'Artiz Indigo 300x300', 'Artiz Mix Cubes 300x300', 'Ash Grey 600x600', 'Ash Monte 600x600', 'Ashley Floor 300x300', 'Ashley HL 600x300', 'Ashley LT 600x300', 'Aston SF 600x600', 'Astoria 600x600', 'AU Black 600x600', 'Autumn Splits 1200x200', 'Aveo SF 600x600', 'Barstow DK 600x300', 'Barstow HL 600x300', 'Barstow LT 600x300', 'Basalt BRN 300x300', 'Belice Wood 800x400', 'Bella Pearl 600x400', 'Bellapapeir FX 1200x600', 'Benalium 600x600', 'Benalium Plus 600x600', 'Benaluim 1200x300', 'Benaluim 1200x600', 'Benicrssin BG 600x300', 'Benimac DK 450x300', 'Benimac Floor 300x300', 'Benimac HL 450x300', 'Benimac LT 450x300', 'BG Bottochino 600x600', 'Bianco White 1200x600', 'Black 300x300', 'Black Cristal Glossy 800x400', 'Black Glossy 800x400', 'Black Portoro 1200x600', 'Blanco Cararra 600x600', 'Blanco Neive 600x300', 'Blanco Neive Kajaria 450x300', 'Blanco Neive Kajaria 600x300', 'Blocks Gris 300x300', 'Bloom Floor 300x300', 'Bloom Flower HL 450x300', 'Bloom LT 450x300', 'Blue 300x300', 'Blue 450x300', 'Boiskraft Stripes 800x400', 'Bookmac HL 1200x600', 'Bottochi Natura 800x800', 'Bottochino Classic Liso 1600x800', 'Bottochino Royal Liso 1200x600', 'Breccia Aurrora 1200x800', 'Bubbles Traventine 450x300', 'Burberry 600x600', 'Cafe Home Decor 600x300', 'Calder Mink 1200x600', 'Caldo Glo Twin 600x400', 'Calista DK 600x300', 'Calista HL 600x300', 'Calista LT 600x300', 'CANDOLIM 600*600', 'Canvera Art HL 800x400', 'Canyan Brown 400x400', 'Canyan Brown Decor 400x400', 'Caranz Dark Grey 15MM 300x300', 'Cardinal Bright 600x300', 'Cardinal Dark 600x300', 'Cardinal Decor 600x300', 'Care Gris 600x600', 'Care Rock 600x600', 'Care Spa 600x600', 'Care Teak 600x600', 'Care Terro', 'Cario Beige Liso 1600x800', 'Carolina Gold 300x300', 'Cartoon', 'Cascade Dusk 450x300', 'Cascade Liso 1600x800', 'Castle Stone BG 600x300', 'Castle Stone Gris 600x300', 'Castle Stone Moss 600x300', 'Cavelo Light Grey 15MM 300x300', 'Cementina GY 300x300', 'Cementoza Decor 600x300', 'Cementoza LT 600x300', 'Cementz Natura 800x800', 'Ceylon Marfil 600x300', 'Ceylon Wood 1200x800', 'Checkered Terra 300x300', 'Chekered Grey 12MM 300x300', 'Chestnut Floor 300x300', 'Chestnut HL 600x300', 'Chestnut LT 600x300', 'Chipstone Gris 600x300', 'Chisel Granite Beige 600x300', 'Chisel Granite DK Grey 600x300', 'Clare Onyx 600x600', 'Classic DK 600x300', 'Classic LT 600x300', 'Classic Pearl 600x600', 'Cliff DK 600x300', 'Cloud DK 450x300', 'Cloud Floor 300x300', 'Cloud HL 450x300', 'Cloud LT 450x300', 'Coated Black 300x300', 'Coated Grey 10MM 300x300', 'Coated Grey 12MM 300x300', 'Coated Grey 15MM 300x30 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-76f085ef45e3> in <module>
# ----> 1 get_match(df.iloc[15821]['Distributor Item code'],a)
#
# <ipython-input-82-0f198c2fce33> in get_match(query, choice, limit)
#       5     print(query)
#       6     print(choice)
# ----> 7     result = process.extract(query,choice,10)
#       8     print(result)
#
# ~/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/process.py in extract(query, choices, processor, scorer, limit)
#     166     """
#     167     sl = extractWithoutOrder(query, choices, processor, scorer)
# --> 168     return heapq.nlargest(limit, sl, key=lambda i: i[1]) if limit is not None else \
#     169         sorted(sl, key=lambda i: i[1], reverse=True)
#     170
#
# ~/anaconda3/lib/python3.7/heapq.py in nlargest(n, iterable, key)
#     567     # General case, slowest method
#     568     it = iter(iterable)
# --> 569     result = [(key(elem), i, elem) for i, elem in zip(range(0, -n, -1), it)]
#     570     if not result:
#     571         return result
#
# ~/anaconda3/lib/python3.7/heapq.py in <listcomp>(.0)
#     567     # General case, slowest method
#     568     it = iter(iterable)
# --> 569     result = [(key(elem), i, elem) for i, elem in zip(range(0, -n, -1), it)]
#     570     if not result:
#     571         return result
#
# ~/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#      76
#      77     # Run the processor on the input query.
# ---> 78     processed_query = processor(query)
#      79
#      80     if len(processed_query) == 0:
#
# TypeError: 'int' object is not callable
